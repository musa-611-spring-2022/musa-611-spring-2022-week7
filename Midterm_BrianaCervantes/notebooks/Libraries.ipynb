# %%
from matplotlib import pyplot as plt
import numpy as np

import osmnx as ox
import pandas as pd
import geopandas as gpd

# %%
bars = ox.geometries_from_place("New Orleans, LA", tags={"amenity": "library"})

# %%
libraries = bars[["name", "geometry"]]

# %%
libraries
# Out:
#                                                                      name  \
# element_type osmid
# node         345315006            Rosa Keller Branch, N.O. Public Library
#              356845113              N. O. Public Library, Mid-City Branch
#              367132633                            Howard Memorial Library
#              367132648     New Orleans Public Library - Nora Navra Branch
#              367132650                         New Orleans Public Library
#              367132683                           Law Library of Louisiana
#              367132684                       Historic New Orleans Library
#              367132685  Children's Resource Center - New Orleans Publi...
#              367132702                           Algiers Regional Library
#              367132703       Central City Branch New Orleans City Library
#              367132704  New Orleans Public Library - Martin Luther Kin...
# ...
